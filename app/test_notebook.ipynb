# %%
from block_extract import _extract_text_as_block
from pathlib import Path

sample_pdf_path = Path("../data/raw/Betalningsintyg.pdf")
extracted_text = _extract_text_as_block(sample_pdf_path)

# %%
extracted_text[0]
# Out:
# [(44.0,
#   55.559879302978516,
#   178.87400817871094,
#   73.55988311767578,
#   'Betalningsintyg\n',
#   0,
#   0),
#  (44.0,
#   100.16436004638672,
#   336.5579528808594,
#   128.27003479003906,
#   'KAMPANJ! Träning abonnemang + friperiod\nStockholm - City\n',
#   1,
#   0),
#  (44.0,
#   157.14659118652344,
#   74.6240005493164,
#   169.14659118652344,
#   'Kund\n',
#   2,
#   0),
#  (44.0,
#   174.11880493164062,
#   207.9299774169922,
#   208.11880493164062,
#   'Oliver Engist\n920401-5359\n1315065\nKundnummer\nPersonnummer\nNamn\n',
#   3,
#   0),
#  (231.0,
#   50.530029296875,
#   419.1498718261719,
#   77.27002716064453,
#   'Utskriftsdatum\nPeriod\n2024-01-01 - 2025-11-04\n2025-11-04\n',
#   4,
#   0),
#  (44.0,
#   127.530029296875,
#   257.4199523925781,
#   141.27003479003906,
#   'Mäster Samuelsgatan 20, 111 44 STOCKHOLM\n',
#   5,
#   0),
#  (365.0,
#   120.61881256103516,
#   474.4699401855469,
#   155.11880493164062,
# ...
